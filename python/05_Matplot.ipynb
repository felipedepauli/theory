# %% [markdown]
# # Começando baixo

# %%
import numpy as np
import matplotlib.pyplot as plt

x0 = np.arange(0, 1000)
y0 = np.sin(x0/50)
plt.plot(x0, y0)

# %%
distance = np.random.randint(0, 20, 100)
print(distance)
frequency = np.random.randint(0, 100, 100)
print(frequency)
plt.scatter(distance, frequency)
# Out:
# [ 0  1  9  6 15 12 16 18 14  7 19  2 11 11 14  9  0  3  3  9 15 12  7 14
#   0  4 18  0  2 10  2  2  1 10 18 16 17  0 12  6  3  5 10 14  3 12 17  0
#   7  5  5 13  5 15 15 11  5  0  4 19 15 19 10  0 15 15  0 19 11 19  5  4
#   5  5 13  0 12  2  1  1 14 19  5 11 17  5  9 11  2  6  0  4 12 14  2 10
#  15 19 17 16]
# [27 73 57 53 77 13 64 68 45 95 38 53 19 85 25 73 26 18 10 84 62 64 21 63
#  37 84 63 11 45 19 44 67 86 52 68 15 86 44 75 33 91  2 37 35 59 77 67  6
#  89 53 87 68 53 79 85 82 28 20 56 39 29 12 95 28 25 96 65 42 75 92 58 19
#  79 16 12 74 90  5 95 11 93  6  0 42 20  6  3 81  9 29  3 96  3  0 42  2
#  28 91 52 46]

# %% [markdown]
# Lindo! E se quisermos plotar algo em escala logarítmica?

# %%
x1 = np.arange(0, 100)
y1 = x1 ** 2

plt.plot(x1, y1)
plt.show()

# %%
y1 = x1 ** 2
plt.plot(x1, y1)
plt.xscale('log')
plt.show()

# %% [markdown]
# # Histograma

# %% [markdown]
# Histograma tem a ver com frequência. Conta-se quantas vezes cada valor aparece. O número contado é o domínio e a sua frequência é a imagem.

# %%
x2 = np.random.randint(0, 100, 100)

print(x2.__len__())
print(len(x2))

plt.hist(x2)
# Out:
# 100
# 100
# (array([ 7., 13., 16.,  9.,  8., 10.,  5., 10., 13.,  9.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
x2 = np.random.randint(0, 100, 50)

plt.hist(x2)
plt.show()


x2 = np.random.randint(0, 100, 50)

plt.hist(x2)
plt.clf()  # Limpa tudo que se escreveu na figura até agora.
plt.show()

x2 = np.random.randint(0, 100, 50)

plt.hist(x2, bins=5)
plt.show()

# %%
x3 = np.arange(0, 20, 0.001)
y3 = 3 ** (-np.exp(x3/10)) * np.cos(x3)
plt.plot(x3, y3)

plt.xlabel('My pretty Axis X')
plt.ylabel('My sweet Axis Y')
plt.title('What a crazy function!')


plt.yticks( [-0.2, -0.05, 0, 0.05, 0.2],
            ["-0.2", "-1/20", "ZERO", "+1/20", "0.2"])

plt.ylim([-0.4, 0.4])

plt.text(1.5, 0.15, 'Such an amazing line!!!', color="orange")
plt.text(0.5, 0.3, 'Here the line begins', color="green")
plt.text(15, 0.02, 'Here de line ends', color="red")

plt.plot()
# Out:
# []
